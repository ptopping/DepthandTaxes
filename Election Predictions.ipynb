# %%
import pandas as pd
import importlib
from DepthandTaxes.tools import fecpull

# %%
importlib.reload(fecpull)
# Out:
# <module 'DepthandTaxes.tools.fecpull' from 'C:\\Users\\ptopp\\Documents\\DepthandTaxes\\DepthandTaxes\\tools\\fecpull.py'>

# %%
fecpull.FECPull('presge',2000).to_csv()
fecpull.FECPull('presprim',2000,is_primary=True).to_csv()
fecpull.FECPull('house',2000,is_pres=False,is_house=True).to_csv()
fecpull.FECPull('senate',2000,is_pres=False).to_csv()
fecpull.FECPull('2002fedresults',2002).to_csv()
fecpull.FECPull('federalelections2004',2004).to_csv()
fecpull.FECPull('federalelections2006',2006).to_csv()
fecpull.FECPull('federalelections2008',2008).to_csv()
fecpull.FECPull('federalelections2010',2010).to_csv()
fecpull.FECPull('federalelections2012',2012).to_csv()
# fecpull.FECPull('federalelections2014',2014).to_csv()
fecpull.FECPull('federalelections2016',2016).to_csv()

# %%
x = fecpull.FECPull('FederalElections2014',2014)
x = x.make_headers(x.house,0)
csv = open('..\\DATFiles\\senate.csv','w')
csv.write(x.to_csv())
csv.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-367-bcc1f2dd277b> in <module>()
#       2 x = x.make_headers(x.house,0)
#       3 csv = open('..\\DATFiles\\senate.csv','w')
# ----> 4 csv.write(x.to_csv())
#       5 csv.close()
#
# ~\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u0101' in position 6777: character maps to <undefined>

# %%
DAT.elections.results.FECLoad('presprim',2000,is_primary=True).pretty()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
T.FECLoad('senate',2000,is_pres=False).pretty()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
T.FECLoad('house',2000,is_pres=False,is_house=True).pretty()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
T.FECLoad('2002fedresults',2002).pretty()
# Out:
#       YEAR      STATE STATEABBREVIATION DISTRICT      FECID  \
# 0     2002    Alabama                AL  Senator  S6AL00195
# 1     2002    Alabama                AL  Senator  S2AL00079
# 2     2002    Alabama                AL  Senator  S2AL00061
# 3     2002    Alabama                AL  Senator  S2AL00087
# 4     2002    Alabama                AL  Senator  S2AL00103
# 5     2002    Alabama                AL  Senator        NaN
# 6     2002    Alabama                AL       01  H2AL01077
# 7     2002    Alabama                AL       01  H2AL01051
# 8     2002    Alabama                AL       01  H2AL01069
# 9     2002    Alabama                AL       01  H2AL00012
# 10    2002    Alabama                AL       01  H2AL01085
# 11    2002    Alabama                AL       01  H2AL01093
# 12    2002    Alabama                AL       01  H2AL01168
# 13    2002    Alabama                AL       01  H2AL01119
# 14    2002    Alabama                AL       01  H2AL01150
# ...

# %%
T.FECLoad('federalelections2004',2004).pretty()
# Out:
#       YEAR       STATE STATEABBREVIATION   DISTRICT      FECID  \
# 0     2004     Alabama                AL  President  P00003335
# 1     2004     Alabama                AL  President  P80000235
# 2     2004     Alabama                AL  President  P20000527
# 3     2004     Alabama                AL  President  P40002537
# 4     2004     Alabama                AL  President  P40003261
# 5     2004     Alabama                AL  President        NaN
# 6     2004      Alaska                AK  President  P00003335
# 7     2004      Alaska                AK  President  P80000235
# 8     2004      Alaska                AK  President  P20000527
# 9     2004      Alaska                AK  President  P40003261
# 10    2004      Alaska                AK  President  P40002537
# 11    2004      Alaska                AK  President  P40003097
# 12    2004      Alaska                AK  President        NaN
# 13    2004     Arizona                AZ  President  P00003335
# ...

# %%
T.FECLoad('federalelections2006',2006).pretty()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
#       YEAR      STATE STATEABBREVIATION DISTRICT      FECID  \
# 1     2006    Alabama                AL       01  H2AL01077
# 2     2006    Alabama                AL       01  H6AL01052
# 3     2006    Alabama                AL       01        NaN
# ...

# %%
T.FECLoad('federalelections2008',2008).pretty()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#       YEAR       STATE STATEABBREVIATION   DISTRICT      FECID  \
# 0     2008     Alabama                AL  President  P80002801
# 1     2008     Alabama                AL  President  P80003338
# 2     2008     Alabama                AL  President  P20000527
# 3     2008     Alabama                AL  President  P80005580
# 4     2008     Alabama                AL  President  P80005499
# 5     2008     Alabama                AL  President        NaN
# 6     2008      Alaska                AK  President  P80002801
# 7     2008      Alaska                AK  President  P80003338
# 8     2008      Alaska                AK  President  P20000527
# ...

# %%
T.FECLoad('federalelections2010',2010).pretty()
# Out:
#       YEAR      STATE STATEABBREVIATION DISTRICT      FECID  \
# 1     2010    Alabama                AL       01  H2AL01077
# 2     2010    Alabama                AL       01  H0AL01030
# 4     2010    Alabama                AL       01  H0AL01048
# 5     2010    Alabama                AL       01        NaN
# 8     2010    Alabama                AL       02  H0AL02087
# 9     2010    Alabama                AL       02  H0AL02103
# 10    2010    Alabama                AL       02  H0AL02111
# 11    2010    Alabama                AL       02  H0AL02129
# 13    2010    Alabama                AL       02  H8AL02130
# 14    2010    Alabama                AL       02        NaN
# 17    2010    Alabama                AL       03  H2AL03032
# 18    2010    Alabama                AL       03  H0AL03184
# 19    2010    Alabama                AL       03        NaN
# 22    2010    Alabama                AL       04  H6AL04098
# 23    2010    Alabama                AL       04        NaN
# ...

# %%
T.FECLoad('federalelections2012',2012).pretty()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#       YEAR       STATE STATEABBREVIATION   DISTRICT      FECID  \
# 0     2012     Alabama                AL  President  P80003353
# 1     2012     Alabama                AL  President  P80003338
# 2     2012     Alabama                AL  President  P20002671
# 3     2012     Alabama                AL  President        NaN
# 4     2012     Alabama                AL  President  P20003984
# 5     2012     Alabama                AL  President  P20004685
# 6     2012      Alaska                AK  President  P80003353
# 7     2012      Alaska                AK  President  P80003338
# 8     2012      Alaska                AK  President  P20002671
# ...

# %%
T.FECLoad('federalelections2014',2014).pretty()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#      YEAR          STATE STATEABBREVIATION DISTRICT       FECID  \
# 1    2014        Alabama                AL       01   H4AL01123
# 2    2014        Alabama                AL       01   H4AL01156
# 3    2014        Alabama                AL       01         NaN
# 6    2014        Alabama                AL       02   H0AL02087
# 7    2014        Alabama                AL       02   H4AL02071
# 8    2014        Alabama                AL       02         NaN
# 11   2014        Alabama                AL       03   H2AL03032
# 12   2014        Alabama                AL       03   H4AL03053
# ...

# %%
T.FECLoad('federalelections2016',2016).pretty().PARTY.unique()
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# array(['REP', 'DEM', 'Independent', 'Write-In', 'Libertarian', 'Green',
#        'Constitution', 'Nonaffiliated', 'Better for America',
#        'Peace and Freedom', 'Unaffiliated', 'American Constitution Party',
#        'Veterans Party of America', 'Independent\xa0American\xa0Party',
#        'Independent People of Colorado', 'American Solidarity Party',
#        'Nutrition Party', 'America’s Party',
#        'Socialism and Liberation Party', 'Socialist Workers Party',
#        'Kotlikoff for President', 'Nonviolent Resistance/Pacifist',
#        'Approval Voting Party', 'Socialist Party USA',
#        'Prohibition Party', 'Statehood Green',
# ...

# %%
census.CensusLoad('sc-est2017-alldata6').projection()
# Out:
# RACE      STATE            DIVISION  YEAR          Asian         Black  \
# 0       Alabama  East South Central  2010   39219.000000  8.566860e+05
# 1       Alabama  East South Central  2011   41194.000000  8.720200e+05
# 2       Alabama  East South Central  2012   43298.000000  8.850370e+05
# 3       Alabama  East South Central  2013   44766.000000  8.985380e+05
# 4       Alabama  East South Central  2014   46341.000000  9.094820e+05
# 5       Alabama  East South Central  2015   48015.000000  9.188490e+05
# 6       Alabama  East South Central  2016   49740.000000  9.252900e+05
# 7       Alabama  East South Central  2017   51739.000000  9.320100e+05
# 8       Alabama  East South Central  2018   52996.257700  9.436601e+05
# 9       Alabama  East South Central  2020   55603.169584  9.673991e+05
# 10      Alabama  East South Central  2024   60293.674012  1.008279e+06
# 11      Alabama  East South Central  2028   65802.940583  1.054631e+06
# ...

# %%
census.CensusLoad('st-est00int-alldata',kind='group').pretty()
# Out:
# RACE          STATE            DIVISION  YEAR   Asian   Black  Hawaiian  \
# 0           Alabama  East South Central  2000   22870  749678       764
# 1           Alabama  East South Central  2001   24130  760381       834
# 2           Alabama  East South Central  2002   25592  767423       876
# 3           Alabama  East South Central  2003   27230  776642       940
# 4           Alabama  East South Central  2004   29218  785183       994
# 5           Alabama  East South Central  2005   31226  797039      1005
# 6           Alabama  East South Central  2006   32996  812993      1122
# 7           Alabama  East South Central  2007   34572  824608      1100
# 8           Alabama  East South Central  2008   36066  837428      1200
# 9           Alabama  East South Central  2009   38361  848223      1241
# 10          Alabama  East South Central  2010   39219  856686      1383
# 11           Alaska             Pacific  2000   17736   13559      1778
# ...

# %%
census2000 = census.CensusLoad('st-est00int-alldata',kind='group').pretty()
census2010 = census.CensusLoad('sc-est2017-alldata6').projection()
df = pd.concat([census2000, census2010],sort=True)
df.columns = df.columns.str.upper()
df.drop_duplicates(inplace=True)

df = df.merge(results.GlobalVariables().df, how='left', left_on='YEAR', right_on='YEAR')

presge2000 = results.FECLoad('presge',2000).pretty()
presprim2000 = results.FECLoad('presprim',2000,is_primary=True).pretty()
pres2000 = presge2000.merge(presprim2000, how='outer', left_on= ['YEAR', 'STATE', 'STATEABBREVIATION', 'DISTRICT', 'CANDIDATENAME', 'PARTY'], 
		right_on=['YEAR', 'STATE', 'STATEABBREVIATION', 'DISTRICT', 'CANDIDATENAME', 'PARTY'])
sen2000 = results.FECLoad('senate',2000,is_pres=False).pretty()
house2000 = results.FECLoad('house',2000,is_pres=False,is_house=True).pretty()
results2000 = pd.concat([pres2000, sen2000, house2000], sort=True)
results2002 = results.FECLoad('2002fedresults',2002).pretty()
results2004 = results.FECLoad('federalelections2004',2004).pretty()
results2006 = results.FECLoad('federalelections2006',2006).pretty()
results2008 = results.FECLoad('federalelections2008',2008).pretty()
results2010 = results.FECLoad('federalelections2010',2010).pretty()
results2012 = results.FECLoad('federalelections2012',2012).pretty()
results2014 = results.FECLoad('federalelections2014',2014).pretty()
results2016 = results.FECLoad('federalelections2016',2016).pretty()
resultsall = pd.concat([results2000,results2002,results2004,results2006,results2008,results2010,results2012,results2014,results2016],sort=True)
resultsall = results.ElectionAnalytics(resultsall).pretty()

df = df.merge(resultsall, how='left', left_on=['YEAR','STATE','PARTY','DISTRICT'], right_on=['YEAR','STATE','PARTY','DISTRICT'])
df.drop(columns=0,inplace=True)
# Out:
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\ptopp\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
results.AllData(df).regression('dataframe').pivot_table(index=['STATE','YEAR'],columns='PARTY').stack(0)
#results.AllData(df).regression('dataframe')[['STATE','YEAR','LOG10(VOTES)','PRELog10(Votes)','RESIDUAL','PREDDICTED VOTES']]
# Out:
# C:\Users\ptopp\documents\depthandtaxes\DepthandTaxes\elections\results.py:652: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dem['PRELog10(Votes)'] = demreg.predict(demX)
# C:\Users\ptopp\documents\depthandtaxes\DepthandTaxes\elections\results.py:653: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   rep['PRELog10(Votes)'] = repreg.predict(repX)
# C:\Users\ptopp\documents\depthandtaxes\DepthandTaxes\elections\results.py:654: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#math.pow(10,5.091997), math.pow(10,5.234177), math.pow(10,-0.142180), math.pow(10,5.091997)/math.pow(10,5.234177)
math.pow(10,0.219264)
# Out:
# 1.6567767829786093

# %%
sns.set_palette('seismic',7)
data = results.AllData(df).cat_var()
g = sns.catplot(data=data, x='Party', y='Log10(Votes)', hue='Party', col='Division', kind='box', col_wrap=3, palette=political_pal)

# %%
x = census.CensusLoad('st-est00int-alldata',kind='group').pretty()
x = x[['STATE','DIVISION']].drop_duplicates('STATE').set_index('STATE')
x.to_dict()
# Out:
# {'DIVISION': {'Alabama': 'East South Central',
#   'Alaska': 'Pacific',
#   'Arizona': 'Mountain',
#   'Arkansas': 'West South Central',
#   'California': 'Pacific',
#   'Colorado': 'Mountain',
#   'Connecticut': 'New England',
#   'Delaware': 'South Atlantic',
#   'District of Columbia': 'South Atlantic',
#   'Florida': 'South Atlantic',
#   'Georgia': 'South Atlantic',
#   'Hawaii': 'Pacific',
#   'Idaho': 'Mountain',
#   'Illinois': 'East North Central',
#   'Indiana': 'East North Central',
#   'Iowa': 'West North Central',
#   'Kansas': 'West North Central',
#   'Kentucky': 'East South Central',
#   'Louisiana': 'West South Central',
#   'Maine': 'New England',
#   'Maryland': 'South Atlantic',
#   'Massachusetts': 'New England',
#   'Michigan': 'East North Central',
#   'Minnesota': 'West North Central',
#   'Mississippi': 'East South Central',
#   'Missouri': 'West North Central',
#   'Montana': 'Mountain',
#   'Nebraska': 'West North Central',
#   'Nevada': 'Mountain',
# ...

# %%
presprim2000
# Out:
# 0
